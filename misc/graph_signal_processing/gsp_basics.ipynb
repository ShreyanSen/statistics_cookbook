# %%
import matplotlib.pyplot as plt
import numpy as np
from pygsp import graphs, plotting
from sklearn.cluster import KMeans
from sklearn.datasets import make_circles
from sklearn.neighbors import radius_neighbors_graph

# %% [markdown]
# following along here:
# https://jcornell616.github.io/graph-theory-and-linear-algebra

# %%
# define parameters
N = 16

# instantiate graph that models sensor network
G = graphs.Sensor(N=4, seed=42)
        
# plot graph
G.plot_signal(G.U[:, 1])
# Out:
# 2023-12-06 20:47:57,128:[WARNING](pygsp.graphs.graph._check_fourier_properties): The Fourier basis G.U is not available, we need to compute the Fourier basis. Explicitly call G.compute_fourier_basis() once beforehand to suppress the warning.

# %%
G.plot_signal(G.U[:, 2])

# %%
G.U[:,1]
# Out:
# array([ 0.12530179, -0.29329119, -0.24391543, -0.08853653,  0.23423362,
#         0.24540247,  0.296914  , -0.23925425, -0.14031404, -0.35035526,
#         0.29196684, -0.28986871, -0.28154538,  0.25117405,  0.2312453 ,
#         0.25084272])

# %%
G.U[:,:]
# Out:
# array([[-0.5       , -0.36065501,  0.72848687,  0.29872202],
#        [-0.5       , -0.3671771 , -0.6830451 ,  0.38552609],
#        [-0.5       , -0.12097525, -0.05207892, -0.85595139],
#        [-0.5       ,  0.84880736,  0.00663715,  0.17170328]])

# %%
G.W[0,1]
# Out:
# 0.8440173714623174

# %%
G.D
