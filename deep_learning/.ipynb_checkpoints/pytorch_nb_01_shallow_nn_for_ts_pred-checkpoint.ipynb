# %% [markdown]
# # Pytorch NB 1
#
# Let's build a very simple NN with pytorch and use it to predict arbitrary time series

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim

# %%
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler

# %%
# generating some time series data
class gen_synth_ts:

    def __init__(self, t_train=200,t_test=20):
        self.t_train = t_train
        self.t_test = t_test
        self.t_length = self.t_train+self.t_test
        np.random.seed(31)
        self.t = np.arange(0,self.t_length)

    def build_random_datasets(self, n_datasets = 1000):
        self.datasets = []

        for i in range(n_datasets):
            self.ar_scale = np.random.uniform(1, 100)
            self.ar_comp = self.ar_scale*self.sim_ar(thetas = [-0.2,0.2])
            self.linear_comp = self.sim_lin(slope = np.random.uniform(-10,10), intercept=np.random.uniform(-10,10))
            self.noise = np.random.normal(0, np.random.uniform(1, 100), self.t_length)
            
            self.cyclic_comps = []
            num_cyclic_comps = np.random.randint(10,1000)
            for i in range(num_cyclic_comps):
                order = np.random.choice([1,2,3])
                freq_bounds = [0.1/(10**order), 1/(10**order)]
                cyclic_comp = self.sim_cyclic(amplitude = np.random.uniform(1,50), frequency=np.random.uniform(freq_bounds[0],freq_bounds[1]), phase=np.random.uniform(-100, 100))
                self.cyclic_comps.append(cyclic_comp)

            dataset = self.ar_comp + self.linear_comp + self.noise + sum(self.cyclic_comps)
            self.datasets.append(dataset)
        
    def plot_dataset(self, dataset_idx):
        plt.figure(figsize=(20,5))
        plt.plot(self.t, self.datasets[dataset_idx], alpha=0.3)
        plt.scatter(self.t, self.datasets[dataset_idx])
        plt.title('Dataset Number ' + str(dataset_idx))
        
    def sim_cyclic(self, amplitude, frequency, phase):
        cyc = amplitude*np.sin(2*np.pi*frequency*(self.t + phase))
        return cyc
        
    def sim_lin(self, slope, intercept):
        lin_val = slope*self.t + intercept
        return lin_val
        
    def sim_ar(self, intercept = 0, thetas = [-0.9,0.9], noise_var = 0.3):
        self.ar_order = len(thetas) # by default it's 2; aka AR(2) process
        X = np.zeros(self.t_length)
        X[:self.ar_order] = intercept
        for i in range(self.ar_order, self.t_length):
            X[i] = np.sum(thetas*np.flip(X[(i-self.ar_order):i])) + np.random.normal(0, noise_var)
        return X

    def sim_poly(self, coeffs = [0, -0.001,0.000002]):
        X = np.zeros(self.t_length)
        for i in range(len(coeffs)):
            X = X + coeffs[i]*self.t**(i+1)
        return X

    def plot_data(self):
        plt.figure(figsize=(20,5))
        plt.plot(self.t, self.data)
        plt.title('Sim Time Series')
        plt.figure(figsize=(20,5))
        plt.scatter(self.t, self.data)
        plt.title('Sim Time Series')

# %%
sts = gen_synth_ts()
sts.build_random_datasets()

# %%
for i in [0,3,10,34,100,250,280,999]:
    sts.plot_dataset(i)

# %% [markdown]
# ok, great, we've built some nice time series datasets. Now let's get to work predicting. For each time series in our training set we'll try to predict the last 20 values from the first 200 values, and then we'll see how our predictions look on the time series we keep in our test set.

# %%
training_datasets = np.array(sts.datasets[0:800])
test_datasets = np.array(sts.datasets[800:1000])

# %% [markdown]
# Let's start with a shallow network!

# %%
class ShallowNeuralNetwork(nn.Module):
    def __init__(self, input_size=200, output_size=20):
        super().__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = 512
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(self.input_size, self.hidden_size),
            nn.ReLU(),
            nn.Linear(self.hidden_size, self.hidden_size),
            nn.ReLU(),
            nn.Linear(self.hidden_size, self.hidden_size),
            nn.ReLU(),
            nn.Linear(self.hidden_size, self.output_size),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
shallow_model = ShallowNeuralNetwork()

# %%
# example pass in 

x = torch.randn(10, shallow_model.input_size)  # Batch size of 10
output = shallow_model(x)
x
# Out:
# tensor([[ 0.0916, -1.0445,  1.1395,  ..., -0.2082,  1.2845,  0.4614],
#         [-1.1959, -0.0591, -0.6076,  ...,  0.1867, -0.0169, -0.3039],
#         [-0.1943, -0.7667,  0.9131,  ...,  1.6484,  0.6744, -1.4354],
#         ...,
#         [-1.7538,  0.2975,  0.4257,  ...,  0.7298, -0.5207, -1.7090],
#         [-1.0553, -0.1533, -0.5056,  ...,  0.7952,  0.1810, -1.2830],
#         [-0.3826, -3.1412,  0.6888,  ..., -0.3980, -1.0673,  0.1803]])

# %%
print(shallow_model)
# Out:
# ShallowNeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=200, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=512, out_features=20, bias=True)
#   )
# )

# %%
shallow_model = ShallowNeuralNetwork()

# bump to torch
X = torch.tensor(training_datasets[:, 0:200], dtype=torch.float32)
y = torch.tensor(training_datasets[:, 200:220], dtype=torch.float32)  # Change to int64 for CrossEntropyLoss

# Create a TensorDataset and DataLoader
dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)  # You can adjust the batch size

# define loss function and optimizer
criterion = nn.MSELoss() 
optimizer = optim.SGD(shallow_model.parameters(), lr=0.0001)

# %%
for batch_X, batch_y in dataloader:
    outputs = shallow_model(batch_X)
outputs.shape
# Out:
# torch.Size([32, 20])

# %%
# Training loop
num_epochs = 10  # You can adjust this
for epoch in range(num_epochs):
    for batch_X, batch_y in dataloader:
        optimizer.zero_grad()  # Zero the gradients
        
        # Forward pass
        outputs = shallow_model(batch_X)  # This should give the predicted values
        
        # Compute the loss
        loss = criterion(outputs, batch_y)  # Outputs and y should both be of shape [batch_size, 20]
        
        # Backward pass
        loss.backward()
        optimizer.step()  # Update weights
        
        # Print loss for monitoring
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/10], Loss: 11156390.0000
# Epoch [1/10], Loss: 1073824315976977708220416.0000
# Epoch [1/10], Loss: inf
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [1/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [9/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan
# Epoch [10/10], Loss: nan

# %% [markdown]
# ### Exploding Loss
#
# What's probably going on is a lack of normalization of the data. Here's what this looks like when we add that component:

# %%
X = torch.tensor(training_datasets[:, 0:200], dtype=torch.float32)
y = torch.tensor(training_datasets[:, 200:220], dtype=torch.float32)  # Change to int64 for CrossEntropyLoss


# Normalize the features
scaler_X = StandardScaler()
X_normalized = scaler_X.fit_transform(X)

# Normalize the targets
scaler_y = StandardScaler()
y_normalized = scaler_y.fit_transform(y)

# Convert to tensors
X_tensor = torch.tensor(X_normalized, dtype=torch.float32)
y_tensor = torch.tensor(y_normalized, dtype=torch.float32)

# Create a TensorDataset and DataLoader
dataset = TensorDataset(X_tensor, y_tensor)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)  # You can adjust the batch size

shallow_model = ShallowNeuralNetwork()

criterion = nn.MSELoss() 
optimizer = optim.SGD(shallow_model.parameters(), lr=0.01)

# Training loop
num_epochs = 30  # You can adjust this
for epoch in range(num_epochs):
    for batch_X, batch_y in dataloader:
        optimizer.zero_grad()  # Zero the gradients
        
        # Forward pass
        outputs = shallow_model(batch_X)  # This should give the predicted values
        
        # Compute the loss
        loss = criterion(outputs, batch_y)  # Outputs and y should both be of shape [batch_size, 20]
        
        # Backward pass
        loss.backward()
        optimizer.step()  # Update weights
        
        # Print loss for monitoring
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# After training, if you need to inverse transform your outputs to get back to the original scale:
# Example: to get predictions back to original scale
# predicted_values = shallow_model(X_tensor).detach().numpy()
# predicted_values_original = scaler_y.inverse_transform(predicted_values)
# Out:
# Epoch [1/30], Loss: 0.9830
# Epoch [1/30], Loss: 0.7133
# Epoch [1/30], Loss: 1.1868
# Epoch [1/30], Loss: 0.9833
# Epoch [1/30], Loss: 0.7842
# Epoch [1/30], Loss: 1.0657
# Epoch [1/30], Loss: 1.1757
# Epoch [1/30], Loss: 0.8537
# Epoch [1/30], Loss: 0.5047
# Epoch [1/30], Loss: 0.7663
# Epoch [1/30], Loss: 0.5311
# Epoch [1/30], Loss: 0.8007
# Epoch [1/30], Loss: 0.6843
# Epoch [1/30], Loss: 0.8079
# Epoch [1/30], Loss: 0.8551
# Epoch [1/30], Loss: 0.4814
# Epoch [1/30], Loss: 0.6283
# Epoch [1/30], Loss: 1.2003
# Epoch [1/30], Loss: 0.5153
# Epoch [1/30], Loss: 0.7025
# Epoch [1/30], Loss: 0.8841
# Epoch [1/30], Loss: 0.6033
# Epoch [1/30], Loss: 0.6646
# Epoch [1/30], Loss: 0.6649
# Epoch [1/30], Loss: 0.6283
# Epoch [2/30], Loss: 0.5539
# Epoch [2/30], Loss: 0.6986
# Epoch [2/30], Loss: 0.5764
# Epoch [2/30], Loss: 0.3781
# Epoch [2/30], Loss: 0.7539
# Epoch [2/30], Loss: 0.4536
# Epoch [2/30], Loss: 0.4339
# Epoch [2/30], Loss: 0.2972
# Epoch [2/30], Loss: 0.5380
# Epoch [2/30], Loss: 0.2630
# Epoch [2/30], Loss: 0.4106
# Epoch [2/30], Loss: 0.4403
# Epoch [2/30], Loss: 0.3097
# Epoch [2/30], Loss: 0.2536
# Epoch [2/30], Loss: 0.3112
# Epoch [2/30], Loss: 0.3575
# Epoch [2/30], Loss: 0.3078
# Epoch [2/30], Loss: 0.2290
# Epoch [2/30], Loss: 0.2399
# Epoch [2/30], Loss: 0.2363
# Epoch [2/30], Loss: 0.2795
# Epoch [2/30], Loss: 0.3119
# Epoch [2/30], Loss: 0.2491
# Epoch [2/30], Loss: 0.1115
# Epoch [2/30], Loss: 0.2497
# Epoch [3/30], Loss: 0.1714
# Epoch [3/30], Loss: 0.2402
# Epoch [3/30], Loss: 0.1393
# Epoch [3/30], Loss: 0.2010
# Epoch [3/30], Loss: 0.1920
# Epoch [3/30], Loss: 0.1814
# Epoch [3/30], Loss: 0.1489
# Epoch [3/30], Loss: 0.1653
# Epoch [3/30], Loss: 0.1159
# Epoch [3/30], Loss: 0.0927
# Epoch [3/30], Loss: 0.1121
# Epoch [3/30], Loss: 0.1248
# Epoch [3/30], Loss: 0.1364
# Epoch [3/30], Loss: 0.1131
# Epoch [3/30], Loss: 0.1250
# Epoch [3/30], Loss: 0.1180
# Epoch [3/30], Loss: 0.1017
# Epoch [3/30], Loss: 0.0857
# Epoch [3/30], Loss: 0.0911
# Epoch [3/30], Loss: 0.0878
# Epoch [3/30], Loss: 0.0852
# Epoch [3/30], Loss: 0.0921
# Epoch [3/30], Loss: 0.0828
# Epoch [3/30], Loss: 0.0838
# Epoch [3/30], Loss: 0.1038
# Epoch [4/30], Loss: 0.0579
# Epoch [4/30], Loss: 0.0794
# Epoch [4/30], Loss: 0.0801
# Epoch [4/30], Loss: 0.1109
# Epoch [4/30], Loss: 0.0811
# Epoch [4/30], Loss: 0.0913
# Epoch [4/30], Loss: 0.0726
# Epoch [4/30], Loss: 0.0886
# Epoch [4/30], Loss: 0.0708
# Epoch [4/30], Loss: 0.0631
# Epoch [4/30], Loss: 0.0939
# Epoch [4/30], Loss: 0.0871
# Epoch [4/30], Loss: 0.0683
# Epoch [4/30], Loss: 0.0681
# Epoch [4/30], Loss: 0.0974
# Epoch [4/30], Loss: 0.0732
# Epoch [4/30], Loss: 0.0819
# Epoch [4/30], Loss: 0.0970
# Epoch [4/30], Loss: 0.0593
# Epoch [4/30], Loss: 0.0635
# Epoch [4/30], Loss: 0.0960
# Epoch [4/30], Loss: 0.0709
# Epoch [4/30], Loss: 0.0881
# Epoch [4/30], Loss: 0.0543
# Epoch [4/30], Loss: 0.0662
# Epoch [5/30], Loss: 0.0634
# Epoch [5/30], Loss: 0.1163
# Epoch [5/30], Loss: 0.0703
# Epoch [5/30], Loss: 0.0703
# Epoch [5/30], Loss: 0.0765
# Epoch [5/30], Loss: 0.0725
# Epoch [5/30], Loss: 0.0880
# Epoch [5/30], Loss: 0.0745
# Epoch [5/30], Loss: 0.0733
# Epoch [5/30], Loss: 0.0788
# Epoch [5/30], Loss: 0.0745
# Epoch [5/30], Loss: 0.0652
# Epoch [5/30], Loss: 0.0729
# Epoch [5/30], Loss: 0.0917
# Epoch [5/30], Loss: 0.0674
# Epoch [5/30], Loss: 0.0599
# Epoch [5/30], Loss: 0.0639
# Epoch [5/30], Loss: 0.0599
# Epoch [5/30], Loss: 0.0502
# Epoch [5/30], Loss: 0.0956
# Epoch [5/30], Loss: 0.0641
# Epoch [5/30], Loss: 0.0697
# Epoch [5/30], Loss: 0.0809
# Epoch [5/30], Loss: 0.0641
# Epoch [5/30], Loss: 0.0713
# Epoch [6/30], Loss: 0.0624
# Epoch [6/30], Loss: 0.0700
# Epoch [6/30], Loss: 0.0602
# Epoch [6/30], Loss: 0.0529
# Epoch [6/30], Loss: 0.0766
# Epoch [6/30], Loss: 0.0802
# Epoch [6/30], Loss: 0.0574
# Epoch [6/30], Loss: 0.0957
# Epoch [6/30], Loss: 0.1014
# Epoch [6/30], Loss: 0.0756
# Epoch [6/30], Loss: 0.0829
# Epoch [6/30], Loss: 0.0611
# Epoch [6/30], Loss: 0.0838
# Epoch [6/30], Loss: 0.0527
# Epoch [6/30], Loss: 0.0850
# Epoch [6/30], Loss: 0.0664
# Epoch [6/30], Loss: 0.0678
# Epoch [6/30], Loss: 0.0575
# Epoch [6/30], Loss: 0.0793
# Epoch [6/30], Loss: 0.0684
# Epoch [6/30], Loss: 0.0736
# Epoch [6/30], Loss: 0.0816
# Epoch [6/30], Loss: 0.0591
# Epoch [6/30], Loss: 0.0815
# Epoch [6/30], Loss: 0.0646
# Epoch [7/30], Loss: 0.0776
# Epoch [7/30], Loss: 0.0700
# Epoch [7/30], Loss: 0.0654
# Epoch [7/30], Loss: 0.0828
# Epoch [7/30], Loss: 0.0706
# Epoch [7/30], Loss: 0.0738
# Epoch [7/30], Loss: 0.0672
# Epoch [7/30], Loss: 0.0776
# Epoch [7/30], Loss: 0.0800
# Epoch [7/30], Loss: 0.0597
# Epoch [7/30], Loss: 0.0642
# Epoch [7/30], Loss: 0.0734
# Epoch [7/30], Loss: 0.0707
# Epoch [7/30], Loss: 0.0570
# Epoch [7/30], Loss: 0.1187
# Epoch [7/30], Loss: 0.0727
# Epoch [7/30], Loss: 0.0754
# Epoch [7/30], Loss: 0.0728
# Epoch [7/30], Loss: 0.0565
# Epoch [7/30], Loss: 0.0539
# Epoch [7/30], Loss: 0.0638
# Epoch [7/30], Loss: 0.0615
# Epoch [7/30], Loss: 0.0717
# Epoch [7/30], Loss: 0.0698
# Epoch [7/30], Loss: 0.0610
# Epoch [8/30], Loss: 0.0712
# Epoch [8/30], Loss: 0.0678
# Epoch [8/30], Loss: 0.1039
# Epoch [8/30], Loss: 0.0668
# Epoch [8/30], Loss: 0.0676
# Epoch [8/30], Loss: 0.0844
# Epoch [8/30], Loss: 0.0966
# Epoch [8/30], Loss: 0.0603
# Epoch [8/30], Loss: 0.0810
# Epoch [8/30], Loss: 0.0727
# Epoch [8/30], Loss: 0.0465
# Epoch [8/30], Loss: 0.0744
# Epoch [8/30], Loss: 0.0529
# Epoch [8/30], Loss: 0.0658
# Epoch [8/30], Loss: 0.0649
# Epoch [8/30], Loss: 0.0686
# Epoch [8/30], Loss: 0.0585
# Epoch [8/30], Loss: 0.0771
# Epoch [8/30], Loss: 0.0705
# Epoch [8/30], Loss: 0.0625
# Epoch [8/30], Loss: 0.0591
# Epoch [8/30], Loss: 0.0645
# Epoch [8/30], Loss: 0.0722
# Epoch [8/30], Loss: 0.0832
# Epoch [8/30], Loss: 0.0478
# Epoch [9/30], Loss: 0.0676
# Epoch [9/30], Loss: 0.0654
# Epoch [9/30], Loss: 0.0646
# Epoch [9/30], Loss: 0.0654
# Epoch [9/30], Loss: 0.0586
# Epoch [9/30], Loss: 0.0786
# Epoch [9/30], Loss: 0.0442
# Epoch [9/30], Loss: 0.0670
# Epoch [9/30], Loss: 0.0716
# Epoch [9/30], Loss: 0.0676
# Epoch [9/30], Loss: 0.0664
# Epoch [9/30], Loss: 0.0656
# Epoch [9/30], Loss: 0.0571
# Epoch [9/30], Loss: 0.0850
# Epoch [9/30], Loss: 0.0772
# Epoch [9/30], Loss: 0.0527
# Epoch [9/30], Loss: 0.0587
# Epoch [9/30], Loss: 0.0873
# Epoch [9/30], Loss: 0.0771
# Epoch [9/30], Loss: 0.0744
# Epoch [9/30], Loss: 0.0791
# Epoch [9/30], Loss: 0.0638
# Epoch [9/30], Loss: 0.0690
# Epoch [9/30], Loss: 0.0730
# Epoch [9/30], Loss: 0.0787
# Epoch [10/30], Loss: 0.0638
# Epoch [10/30], Loss: 0.0621
# Epoch [10/30], Loss: 0.0601
# Epoch [10/30], Loss: 0.0698
# Epoch [10/30], Loss: 0.0761
# Epoch [10/30], Loss: 0.0828
# Epoch [10/30], Loss: 0.0669
# Epoch [10/30], Loss: 0.0796
# Epoch [10/30], Loss: 0.0708
# Epoch [10/30], Loss: 0.0651
# Epoch [10/30], Loss: 0.0607
# Epoch [10/30], Loss: 0.0739
# Epoch [10/30], Loss: 0.0766
# Epoch [10/30], Loss: 0.0918
# Epoch [10/30], Loss: 0.0536
# Epoch [10/30], Loss: 0.0655
# Epoch [10/30], Loss: 0.0555
# Epoch [10/30], Loss: 0.0544
# Epoch [10/30], Loss: 0.0727
# Epoch [10/30], Loss: 0.0591
# Epoch [10/30], Loss: 0.0667
# Epoch [10/30], Loss: 0.0431
# Epoch [10/30], Loss: 0.0684
# Epoch [10/30], Loss: 0.0768
# Epoch [10/30], Loss: 0.0761
# Epoch [11/30], Loss: 0.0669
# Epoch [11/30], Loss: 0.0801
# Epoch [11/30], Loss: 0.0558
# Epoch [11/30], Loss: 0.0693
# Epoch [11/30], Loss: 0.0860
# Epoch [11/30], Loss: 0.0563
# Epoch [11/30], Loss: 0.0805
# Epoch [11/30], Loss: 0.0440
# Epoch [11/30], Loss: 0.0457
# Epoch [11/30], Loss: 0.0842
# Epoch [11/30], Loss: 0.0728
# Epoch [11/30], Loss: 0.0505
# Epoch [11/30], Loss: 0.0645
# Epoch [11/30], Loss: 0.0650
# Epoch [11/30], Loss: 0.0611
# Epoch [11/30], Loss: 0.0618
# Epoch [11/30], Loss: 0.0602
# Epoch [11/30], Loss: 0.0567
# Epoch [11/30], Loss: 0.0685
# Epoch [11/30], Loss: 0.0590
# Epoch [11/30], Loss: 0.0569
# Epoch [11/30], Loss: 0.0932
# Epoch [11/30], Loss: 0.0902
# Epoch [11/30], Loss: 0.0828
# Epoch [11/30], Loss: 0.0569
# Epoch [12/30], Loss: 0.0491
# Epoch [12/30], Loss: 0.0739
# Epoch [12/30], Loss: 0.0700
# Epoch [12/30], Loss: 0.0729
# Epoch [12/30], Loss: 0.0597
# Epoch [12/30], Loss: 0.0557
# Epoch [12/30], Loss: 0.0619
# Epoch [12/30], Loss: 0.0645
# Epoch [12/30], Loss: 0.0455
# Epoch [12/30], Loss: 0.0501
# Epoch [12/30], Loss: 0.0585
# Epoch [12/30], Loss: 0.0651
# Epoch [12/30], Loss: 0.0593
# Epoch [12/30], Loss: 0.0803
# Epoch [12/30], Loss: 0.0817
# Epoch [12/30], Loss: 0.0702
# Epoch [12/30], Loss: 0.1110
# Epoch [12/30], Loss: 0.0389
# Epoch [12/30], Loss: 0.0701
# Epoch [12/30], Loss: 0.0849
# Epoch [12/30], Loss: 0.0687
# Epoch [12/30], Loss: 0.0723
# Epoch [12/30], Loss: 0.0676
# Epoch [12/30], Loss: 0.0501
# Epoch [12/30], Loss: 0.0644
# Epoch [13/30], Loss: 0.0688
# Epoch [13/30], Loss: 0.0589
# Epoch [13/30], Loss: 0.0663
# Epoch [13/30], Loss: 0.0803
# Epoch [13/30], Loss: 0.0593
# Epoch [13/30], Loss: 0.0538
# Epoch [13/30], Loss: 0.0650
# Epoch [13/30], Loss: 0.0460
# Epoch [13/30], Loss: 0.0584
# Epoch [13/30], Loss: 0.0735
# Epoch [13/30], Loss: 0.0870
# Epoch [13/30], Loss: 0.0558
# Epoch [13/30], Loss: 0.0653
# Epoch [13/30], Loss: 0.1030
# Epoch [13/30], Loss: 0.0836
# Epoch [13/30], Loss: 0.0652
# Epoch [13/30], Loss: 0.0530
# Epoch [13/30], Loss: 0.0507
# Epoch [13/30], Loss: 0.0586
# Epoch [13/30], Loss: 0.0744
# Epoch [13/30], Loss: 0.0798
# Epoch [13/30], Loss: 0.0477
# Epoch [13/30], Loss: 0.0514
# Epoch [13/30], Loss: 0.0686
# Epoch [13/30], Loss: 0.0513
# Epoch [23/30], Loss: 0.0623
# Epoch [23/30], Loss: 0.0556
# Epoch [23/30], Loss: 0.0449
# Epoch [23/30], Loss: 0.0583
# Epoch [23/30], Loss: 0.0614
# Epoch [23/30], Loss: 0.0763
# Epoch [23/30], Loss: 0.0344
# Epoch [23/30], Loss: 0.0630
# Epoch [23/30], Loss: 0.0441
# Epoch [23/30], Loss: 0.0662
# Epoch [23/30], Loss: 0.0521
# Epoch [23/30], Loss: 0.0828
# Epoch [24/30], Loss: 0.0622
# Epoch [24/30], Loss: 0.0426
# Epoch [24/30], Loss: 0.0712
# Epoch [24/30], Loss: 0.0607
# Epoch [24/30], Loss: 0.0580
# Epoch [24/30], Loss: 0.0738
# Epoch [24/30], Loss: 0.0476
# Epoch [24/30], Loss: 0.0535
# Epoch [24/30], Loss: 0.0436
# Epoch [24/30], Loss: 0.0494
# Epoch [24/30], Loss: 0.0636
# Epoch [24/30], Loss: 0.0530
# Epoch [24/30], Loss: 0.0684
# Epoch [24/30], Loss: 0.0620
# Epoch [24/30], Loss: 0.0515
# Epoch [24/30], Loss: 0.0502
# Epoch [24/30], Loss: 0.0531
# Epoch [24/30], Loss: 0.0593
# Epoch [24/30], Loss: 0.0481
# Epoch [24/30], Loss: 0.0644
# Epoch [24/30], Loss: 0.0643
# Epoch [24/30], Loss: 0.0477
# Epoch [24/30], Loss: 0.0701
# Epoch [24/30], Loss: 0.0755
# Epoch [24/30], Loss: 0.0412
# Epoch [25/30], Loss: 0.0380
# Epoch [25/30], Loss: 0.0603
# Epoch [25/30], Loss: 0.0497
# Epoch [25/30], Loss: 0.0446
# Epoch [25/30], Loss: 0.0570
# Epoch [25/30], Loss: 0.0551
# Epoch [25/30], Loss: 0.0480
# Epoch [25/30], Loss: 0.0505
# Epoch [25/30], Loss: 0.0562
# Epoch [25/30], Loss: 0.0605
# Epoch [25/30], Loss: 0.0620
# Epoch [25/30], Loss: 0.0599
# Epoch [25/30], Loss: 0.0532
# Epoch [25/30], Loss: 0.0742
# Epoch [25/30], Loss: 0.0643
# Epoch [25/30], Loss: 0.0512
# Epoch [25/30], Loss: 0.0526
# Epoch [25/30], Loss: 0.0688
# Epoch [25/30], Loss: 0.0418
# Epoch [25/30], Loss: 0.0551
# Epoch [25/30], Loss: 0.0642
# Epoch [25/30], Loss: 0.0657
# Epoch [25/30], Loss: 0.0755
# Epoch [25/30], Loss: 0.0599
# Epoch [25/30], Loss: 0.0500
# Epoch [26/30], Loss: 0.0643
# Epoch [26/30], Loss: 0.0627
# Epoch [26/30], Loss: 0.0522
# Epoch [26/30], Loss: 0.0511
# Epoch [26/30], Loss: 0.0330
# Epoch [26/30], Loss: 0.0654
# Epoch [26/30], Loss: 0.0448
# Epoch [26/30], Loss: 0.0509
# Epoch [26/30], Loss: 0.0500
# Epoch [26/30], Loss: 0.0557
# Epoch [26/30], Loss: 0.0803
# Epoch [26/30], Loss: 0.0654
# Epoch [26/30], Loss: 0.0687
# Epoch [26/30], Loss: 0.0579
# Epoch [26/30], Loss: 0.0650
# Epoch [26/30], Loss: 0.0653
# Epoch [26/30], Loss: 0.0401
# Epoch [29/30], Loss: 0.0327
# Epoch [29/30], Loss: 0.0694
# Epoch [29/30], Loss: 0.0588
# Epoch [29/30], Loss: 0.0496
# Epoch [30/30], Loss: 0.0544
# Epoch [30/30], Loss: 0.0485
# Epoch [30/30], Loss: 0.0601
# Epoch [30/30], Loss: 0.0596
# Epoch [30/30], Loss: 0.0504
# Epoch [30/30], Loss: 0.0628
# Epoch [30/30], Loss: 0.0574
# Epoch [30/30], Loss: 0.0484
# Epoch [30/30], Loss: 0.0517
# Epoch [30/30], Loss: 0.0514
# Epoch [30/30], Loss: 0.0504
# Epoch [30/30], Loss: 0.0579
# Epoch [30/30], Loss: 0.0463
# Epoch [30/30], Loss: 0.0641
# Epoch [30/30], Loss: 0.0504
# Epoch [30/30], Loss: 0.0558
# Epoch [30/30], Loss: 0.0512
# Epoch [30/30], Loss: 0.0504
# Epoch [30/30], Loss: 0.0423
# Epoch [30/30], Loss: 0.0553
# Epoch [30/30], Loss: 0.0600
# Epoch [30/30], Loss: 0.0570
# Epoch [30/30], Loss: 0.0520
# Epoch [30/30], Loss: 0.0562
# Epoch [30/30], Loss: 0.0558

# %%
# let's see our performance

X_pred = torch.tensor(test_datasets[:, 0:200], dtype=torch.float32)
#y_pred = torch.tensor(test_datasets[:, 200:220], dtype=torch.float32)  # Change to int64 for CrossEntropyLoss
y_pred = shallow_model(X_pred)

# %%
y_pred
# Out:
# tensor([[4332.4028, 4385.4438, 4411.1924,  ..., 4462.7690, 4486.1807,
#          4239.7656],
#         [  75.5083,   57.9850,   34.3924,  ...,    7.6148,   81.2601,
#            52.3072],
#         [1514.5642, 1533.8569, 1500.3701,  ..., 1564.7456, 1576.8696,
#          1536.7605],
#         ...,
#         [ 887.4926,  805.0371,  870.1810,  ...,  964.6080,  892.2201,
#           837.0883],
#         [ 978.1632,  967.4377,  912.2349,  ...,  987.5837,  951.7152,
#           953.2228],
#         [ 345.1454,  349.9511,  388.9146,  ...,  392.7773,  410.7318,
#           410.6753]], grad_fn=<AddmmBackward0>)

# %%
y_pred_np = y_pred.detach().numpy()

# %%
y_pred_np.shape
# Out:
# (200, 20)

# %%
projections = np.append(test_datasets[:, 0:200], y_pred_np, axis=1)

# %%
def plot_projected_value(i, ds_real, ds_proj):
    plt.figure(figsize=(18,5))
    plt.plot(ds_real[i, :], label= 'real data')
    plt.plot(ds_proj[i,:], linestyle='--', label='proj data')
    plt.axvline(200-1, linestyle='--', color='green', label='present', alpha=0.4)
    plt.title('Test dataset ' + str(i) + ' Total dataset ' + str(800+i))
    plt.legend()
    sts.plot_dataset(800+i)

# %%
plot_projected_value(10, test_datasets, projections)

# %%
plot_projected_value(100, test_datasets, projections)

# %%
plot_projected_value(101, test_datasets, projections)

# %%
for i in range(0,10):
    plot_projected_value(i, test_datasets, projections)

# %% [markdown]
# # Conclusion
#
# As we might expect, our shallow net with just a few hundred training examples didn't do so well. It's pretty interesting to see though!
# It's also kind of cool that in the last few plots we see it has the same "strategy"--a sharp drop and then holding steady. It probably learned at least one thing about time series--often, the last seen value isn't such a bad guess! If you haven't picked up any real knowledge of the underlying structure, it's the 0th order guess of choice.
