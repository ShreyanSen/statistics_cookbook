# %% [markdown]
# # Time Series Modeling
#
# We'll start out with a pretty straight-forward situation and add complexity.
# Inspiration from the guide here:
# https://www.pymc.io/projects/examples/en/latest/time_series/Forecasting_with_structural_timeseries.html#complicating-the-picture-further
#
# and look at the pm.AR documentation here:
# https://www.pymc.io/projects/docs/en/stable/api/distributions/generated/pymc.AR.html
#
#
#
#
# ### Generate + Solve AR Process
#
# We'll start with an autoregressive process

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymc as pm
import arviz as az
import xarray as xr
import matplotlib.pyplot as plt
#from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
az.style.use('arviz-darkgrid')

# %%
np.random.seed(34)
def sim_ar(intercept = 10, thetas = [-0.9,0.9], noise_var = 0.3, steps=500):
    X = np.zeros(steps)
    order = len(thetas) # by default it's 2; aka AR(2) process
    X[:order] = intercept
    for i in range(order, steps):
        X[i] = np.sum(thetas*np.flip(X[(i-order):i])) + np.random.normal(0, noise_var)
    return X

# %%
data = sim_ar(thetas = [-0.9,0.1])

# %%
plt.plot(data)

# %%
plot_acf(data)
plt.show()

# %%
plot_pacf(data)
plt.show()

# %% [markdown]
# ## Bayesian AR Model
#
# Now, let's do some Bayesian modeling.

# %%
# setting up dict of priors
priors = {
    "coefs": {"mu": [0, 0], "sigma": [1, 1], "size": 2},
    "sigma": 1,
    "init": {"mu": 10, "sigma": 3, "size": 2},
}
#conceit is we pretty much know the initial value;
# we need a prior each for each coefficient; here we'll go AR(2)

# split data into test and train
split = 300
data_train = data[0:split]
data_test = data[split:]
#t_data = list(range(split))
t_data = np.arange(split)

# %%
with pm.Model() as AR:
    np.random.seed(82341)
    AR.add_coord("obs_id", t_data, mutable=True) # coords, mutable for prediction

    # data containers for time and 
    t = pm.MutableData("t", t_data, dims="obs_id")
    y = pm.MutableData("y", data_train, dims="obs_id")

    # now we build our priors for the AR model parameters

    # rho in the API, one per autoregression coefficient
    coefs = pm.Normal("coefs", priors["coefs"]["mu"], priors["coefs"]["sigma"])
    # standard deviation of our normal noise term
    sigma = pm.HalfNormal("sigma", priors["sigma"])
    # We need one init variable for each lag, hence size is variable too
    init = pm.Normal.dist(
        priors["init"]["mu"], priors["init"]["sigma"], size=priors["init"]["size"]
    )

    ar = pm.AR(
        "ar",
        coefs,
        sigma=sigma,
        init_dist=init,
        constant=False,
        dims="obs_id",
    )
    outcome = pm.Normal("likelihood", mu=ar, sigma=sigma, observed=y, dims="obs_id")

    idata_ar = pm.sample_prior_predictive()
    idata_ar.extend(pm.sample(2000, random_seed=100, target_accept=0.95))
    idata_ar.extend(pm.sample_posterior_predictive(idata_ar))
# Out:
# Sampling: [ar, coefs, likelihood, sigma]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [coefs, sigma, ar]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:27&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 28 seconds.
# Sampling: [likelihood]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00&lt;00:00]
#     </div>

# %%
az.plot_trace(idata_ar, figsize=(10, 6), kind="rank_vlines"); # yup we did well!

# %%
az.summary(idata_ar, var_names=["~ar"])
# Out:
#            mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# coefs[0] -0.912  0.016  -0.944   -0.883        0.0      0.0    5979.0
# coefs[1]  0.088  0.016   0.058    0.118        0.0      0.0    6010.0
# sigma     0.202  0.008   0.186    0.217        0.0      0.0    4086.0
#
#           ess_tail  r_hat
# coefs[0]    5925.0    1.0
# coefs[1]    5884.0    1.0
# sigma       5376.0    1.0

# %%
az.summary(idata_ar, var_names=["ar"])
# Out:
#            mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# ar[0]    10.011  0.206   9.627   10.400      0.002    0.001    9747.0
# ar[1]     9.833  0.200   9.443   10.194      0.003    0.002    5328.0
# ar[2]    -8.009  0.171  -8.332   -7.687      0.002    0.002    4917.0
# ar[3]     7.973  0.140   7.698    8.230      0.002    0.001    7735.0
# ar[4]    -7.799  0.137  -8.061   -7.546      0.002    0.001    7634.0
# ...         ...    ...     ...      ...        ...      ...       ...
# ar[295]   7.592  0.135   7.339    7.842      0.002    0.001    7404.0
# ar[296]  -7.507  0.138  -7.772   -7.258      0.002    0.001    8082.0
# ar[297]   7.386  0.136   7.138    7.644      0.002    0.001    7697.0
# ar[298]  -7.436  0.142  -7.698   -7.161      0.002    0.001    6943.0
# ar[299]   7.497  0.160   7.201    7.800      0.002    0.001    8024.0
#
#          ess_tail  r_hat
# ar[0]      6271.0    1.0
# ar[1]      6279.0    1.0
# ar[2]      5737.0    1.0
# ar[3]      6248.0    1.0
# ar[4]      6107.0    1.0
# ...           ...    ...
# ar[295]    5599.0    1.0
# ar[296]    5956.0    1.0
# ar[297]    6129.0    1.0
# ar[298]    5931.0    1.0
# ar[299]    6368.0    1.0
#
# [300 rows x 9 columns]

# %%
idata_ar.posterior.ar.mean(["chain", "draw"]).plot(label="Posterior Mean AR level")
plt.plot(data_train,'o',color="black", markersize=2, label="Observed Data")
plt.legend()

# %%
idata_ar
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> sample_stats
# 	> prior
# 	> prior_predictive
# 	> observed_data
# 	> constant_data

# %% [markdown]
# ## Prediction Step
#
# This method is pretty wonky. Since we have a two term lag we first have to create a new AR object with lag (meaning we need support over the last two values in the training data) and only then can we continue.

# %%
num_lags = priors["init"]["size"]
with AR:
    AR.add_coords({"obs_id_fut_lagged": range(len(data_train) - num_lags,len(data_test)+len(data_train),1 )})
    AR.add_coords({"obs_id_fut": range(len(data_train),len(data_test)+len(data_train),1 )})

    ar_fut = pm.AR(
        "ar_fut",
        init_dist=pm.DiracDelta.dist(ar[..., -num_lags]),
        rho=coefs,
        sigma=sigma,
        constant=False,
        dims="obs_id_fut_lagged",
    )

    yhat_fut = pm.Normal("yhat_fut", mu=ar_fut[num_lags:], sigma=sigma, dims="obs_id_fut")

    # use the updated values and predict outcomes and probabilities:
    idata_preds = pm.sample_posterior_predictive(
        idata_ar, var_names=["likelihood", "yhat_fut"], predictions=True, random_seed=100
    )
# Out:
# Sampling: [ar_fut, likelihood, yhat_fut]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:33&lt;00:00]
#     </div>

# %%
pm.model_to_graphviz(AR)

# %%
idata_preds.predictions
# Out:
# <xarray.Dataset>
# Dimensions:     (chain: 4, draw: 2000, obs_id: 300, obs_id_fut: 200)
# Coordinates:
#   * chain       (chain) int64 0 1 2 3
#   * draw        (draw) int64 0 1 2 3 4 5 6 ... 1994 1995 1996 1997 1998 1999
#   * obs_id      (obs_id) int64 0 1 2 3 4 5 6 7 ... 293 294 295 296 297 298 299
#   * obs_id_fut  (obs_id_fut) int64 300 301 302 303 304 ... 495 496 497 498 499
# Data variables:
#     likelihood  (chain, draw, obs_id) float64 10.02 9.707 ... -7.324 7.013
#     yhat_fut    (chain, draw, obs_id_fut) float64 7.012 -6.842 ... 4.974 -5.067
# Attributes:
#     created_at:                 2024-09-14T18:16:01.976302
#     arviz_version:              0.16.1
#     inference_library:          pymc
#     inference_library_version:  5.10.2

# %%
np.quantile(idata_preds.predictions.yhat_fut, 0.9)
# Out:
# 7.430451962228059

# %%
np.quantile(idata_preds.predictions.yhat_fut, 0.8, axis=[0,1])
# Out:
# array([ 6.52205727, -5.94667739,  6.6589027 , -5.85568534,  6.7218446 ,
#        -5.80082935,  6.76739534, -5.72723219,  6.81711764, -5.67634675,
#         6.83948025, -5.6267217 ,  6.87522151, -5.5651559 ,  6.91104392,
#        -5.53273876,  6.92539192, -5.47759025,  6.96494118, -5.45334102,
#         6.98883264, -5.40377462,  7.01320722, -5.34768395,  7.04848256,
#        -5.32663151,  7.06749553, -5.28784817,  7.11565178, -5.27429171,
#         7.14488679, -5.22902144,  7.15829394, -5.18956746,  7.17911429,
#        -5.13419718,  7.18578265, -5.11989934,  7.21117309, -5.11039341,
#         7.22263595, -5.06600363,  7.23274862, -5.01475299,  7.2580815 ,
#        -5.00548654,  7.24994891, -4.97578267,  7.25945962, -4.9189775 ,
#         7.27821258, -4.90649215,  7.29749931, -4.86491598,  7.32751563,
#        -4.80813507,  7.33483496, -4.79036683,  7.37766346, -4.7559116 ,
#         7.37630927, -4.74128435,  7.36667288, -4.69318721,  7.38655834,
#        -4.6961513 ,  7.42557715, -4.63629758,  7.39788708, -4.62756172,
#         7.42395885, -4.60097538,  7.46146182, -4.57076435,  7.46556375,
#        -4.55422213,  7.49522151, -4.53497433,  7.4912734 , -4.50936102,
#         7.48349433, -4.47772405,  7.49567296, -4.46344052,  7.51326441,
#        -4.4344684 ,  7.56648486, -4.41751001,  7.56435099, -4.36887236,
#         7.5543489 , -4.35700155,  7.58139609, -4.33610745,  7.60063454,
#        -4.32461884,  7.5996345 , -4.30094711,  7.61216032, -4.25058241,
#         7.62173096, -4.2553601 ,  7.63218383, -4.22130311,  7.64618355,
#        -4.1916155 ,  7.6433914 , -4.155524  ,  7.66896289, -4.14218852,
#         7.64253127, -4.11400386,  7.68355425, -4.08252319,  7.67799948,
#        -4.06348926,  7.70160334, -4.03326688,  7.70781197, -4.01811966,
#         7.70680242, -4.02776481,  7.70446627, -3.99183657,  7.71062558,
#        -3.98703011,  7.75585469, -3.96420933,  7.76373054, -3.92076371,
#         7.77835987, -3.9020246 ,  7.77170883, -3.87689159,  7.78532991,
#        -3.84375827,  7.78933721, -3.8268372 ,  7.80674154, -3.80497179,
#         7.82204813, -3.78109687,  7.84146312, -3.76829068,  7.83002249,
#        -3.76214964,  7.83213314, -3.73619717,  7.86045081, -3.70844068,
#         7.86090634, -3.68490707,  7.89863173, -3.66551012,  7.89605464,
#        -3.64968685,  7.94490257, -3.66100652,  7.91888393, -3.61733758,
#         7.95068494, -3.57427029,  7.93855773, -3.57639667,  7.95005185,
#        -3.5388016 ,  7.95305033, -3.49404322,  7.9931002 , -3.50016021,
#         7.99870254, -3.47133476,  7.98884286, -3.44259765,  7.99067472,
#        -3.44088235,  7.971286  , -3.4372228 ,  8.02045838, -3.38804961,
#         8.03066775, -3.39073187,  8.01670896, -3.37210101,  8.06961193,
#        -3.35583666,  8.08754136, -3.36721413,  8.09190432, -3.31320485,
#         8.12727716, -3.29511201,  8.11481169, -3.2731139 ,  8.17836829,
#        -3.28340939,  8.10123549, -3.24673565,  8.11422071, -3.22393216])

# %%
plt.plot(idata_preds.predictions.yhat_fut.mean(["chain", "draw"]), label="Predictions")
plt.plot(np.quantile(idata_preds.predictions.yhat_fut, 0.99, axis=[0,1]), color='green', label="98% Quantile")
plt.plot(np.quantile(idata_preds.predictions.yhat_fut, 0.01, axis=[0,1]), color='green')


plt.plot(data_test,'o',color="black", markersize=2, label="Observed Data")
plt.legend()

# %% [markdown]
# ### Results Above
#
# Well these results look fairly consistent with what they're getting on the tutorial (for different params and a slightly different model--I drop the intercept after initializing the ts leading to changes in things like the number of parameters). But I wouldn't call the results good. Real performance significantly steps outside of our intervals. That's probably to be expected; but I also am not totally sure the syntax is right here. When we pass "coefs" back in are we passing the posterior coefficients, or the priors we created earlier?
#
# update: ok re-running with another random seed we avoided the appearance of this issue...but I'm still not sure this is the right way to do this.
#
# Let's leave it for now...

# %% [markdown]
# ## Time Series Projections With PyMC
#
# I want to demonstrate to myself that we can run prediction forward in time by using the same parameters (this is a syntax issue not a theory issue). I'll do it by running a very simple linear regression, fitting it over a training range, and then extending to a test range

# %%
timesteps = 200
t = np.arange(timesteps)
theta = 5
noise = np.random.normal(0,20, timesteps)
y = theta*t + noise

# %%
plt.plot(t, y, label="data")
plt.title("Data No Projections")
plt.legend()

# %%
with pm.Model() as linmod:
    linmod.add_coords({"obs_id": range(timesteps)})
    
    time = pm.MutableData("t", t, dims="obs_id")
    vals = pm.MutableData("y", y, dims="obs_id")
    params = pm.Normal("params", 0,10)
    sigma = pm.HalfNormal("sigma", 5)
    mu = params*time
    obs = pm.Normal("obs", mu, sigma, observed=vals, dims="obs_id")


    #trace = pm.sample(draws=1000,tune=1000)

# %%
#trace.posterior.params 
# yup so we were able to converge on the right answer here
# later tried seeing if it works if I don't run the original sample

# %%
projection_steps = 200
with linmod:
    linmod.add_coords({"obs_id_fut": range(timesteps,timesteps+projection_steps,1 )})

    t_fut = pm.MutableData(
        "t_fut", list(range(timesteps, timesteps+projection_steps, 1)), dims="obs_id_fut"
    )
    mu = pm.Deterministic("mu_fut", params * t_fut, dims="obs_id_fut")
    yhat_fut = pm.Normal("yhat_fut", mu=mu, sigma=sigma, dims="obs_id_fut")

    trace_future = pm.sample(draws=1000,tune=1000)

    # use the updated values and predict outcomes and probabilities:
    trace_future =  pm.sample(draws=1000,tune=1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [params, sigma, yhat_fut]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:03&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 4 seconds.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [params, sigma, yhat_fut]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:03&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 3 seconds.

# %%
pm.model_to_graphviz(linmod)

# %%
plt.plot(t,y, label='data')
plt.plot(np.arange(timesteps, timesteps+projection_steps,1), trace_future.posterior.yhat_fut.mean(['chain','draw']), label='projected trend')
plt.title('Data With Projections')
plt.legend()

# %% [markdown]
# ## Conclusion
#
# Ok, I believe it now. The syntax works just fine. We're able to use the same parameters (that we originally set to some prior) and when we project with them we'll use the posterior fit we arrive at in the end. If I was using my prior for theta here I'd see a flat line because the prior was N(0,10). Instead, we're clearly using the posterior slope which is 5.

# %% [markdown]
# ## Adding Trend and Seasonal Terms
#
# To complicate our picture more let's add some trend and seasonal terms to the data and then see if we're able to recover them. For trend we'll just add a term that's linear with time. This follows roughly what the tutorial is doing but let's model it in our own way.

# %%
class gen_synth_data:

    def __init__(self, t_train=300,t_test=200 ):
        self.t_train = t_train
        self.t_test = t_test
        self.t_length = self.t_train+self.t_test
        np.random.seed(321)
        self.t = np.arange(0,self.t_length)
        
        
            
    
    def build_custom_data(self):

        self.ar_comp = self.sim_ar(thetas = [-0.7,0.1])
        self.linear_comp = self.sim_lin(slope=0.008, intercept=0)
        self.seasonal_comp = self.sim_cyclic(amplitude = 4, frequency=(1/50), phase=0)

        self.data = self.ar_comp+self.linear_comp+self.seasonal_comp

    def plot_custom_data(self):
        
        plt.figure(figsize=(20,5))
        plt.plot(self.t, self.data)
        plt.title('Data')
    
        plt.figure(figsize=(20,5))
        plt.plot(self.t, self.ar_comp)
        plt.title('AR')
    
        plt.figure(figsize=(20,5))
        plt.plot(self.t, self.linear_comp)
        plt.title('linear')
    
        plt.figure(figsize=(20,5))
        plt.plot(self.t, self.seasonal_comp)
        plt.title('seasonal')

    
    def sim_cyclic(self, amplitude, frequency, phase):
        cyc = amplitude*np.sin(2*np.pi*frequency*(self.t + phase))
        return cyc
        
    def sim_lin(self, slope, intercept):
        lin_val = slope*self.t + intercept
        return lin_val
        
    def sim_ar(self, intercept = 10, thetas = [-0.9,0.9], noise_var = 0.3):
        self.ar_order = len(thetas) # by default it's 2; aka AR(2) process
        X = np.zeros(self.t_length)
        X[:self.ar_order] = intercept
        for i in range(self.ar_order, self.t_length):
            X[i] = np.sum(thetas*np.flip(X[(i-self.ar_order):i])) + np.random.normal(0, noise_var)
        return X

# %%
data_gen = gen_synth_data()
data_gen.build_custom_data()

# %%
data_gen.plot_custom_data()

# %%
class sbts_model:

    def __init__(self, data_obj, priors = {
            "coefs": {"mu": [0, 0], "sigma": [1, 1], "size": 2},
            "sigma": 1,
            "init": {"mu": 10, "sigma": 3, "size": 2},
            "alpha":{"mu":0, "sigma":5},
            "beta":{"mu":0.2, "sigma":1},
            "amp":{"mu":10, "sigma":5},
            "freq":{"alpha":1,"beta":20}
        }):

        self.priors = priors

        self.data_obj = data_obj
        np.random.seed(9274)

        self.ar_order = data_obj.ar_order
        self.data = data_obj.data
        
        self.train_length = data_obj.t_train
        self.test_length = data_obj.t_test
        self.total_length = data_obj.t_length
        
        self.t_train = np.arange(self.train_length)
        self.t_test = np.arange(self.train_length, self.total_length)

        self.data_train = self.data[0:self.train_length]
        self.data_test = self.data[self.train_length:self.total_length]
        
    def run_model(self):

        with pm.Model() as SBTS:
        
            SBTS.add_coord("obs_id", self.t_train, mutable=True) # coords, mutable for prediction
        
            # data containers for time and 
            t = pm.MutableData("t", self.t_train, dims="obs_id")
            y = pm.MutableData("y", self.data_train, dims="obs_id")
        
            # now we build our priors for the AR model parameters
        
            # rho in the API, one per autoregression coefficient
            coefs = pm.Normal("coefs", self.priors["coefs"]["mu"], self.priors["coefs"]["sigma"])
            # standard deviation of our normal noise term
            sigma = pm.HalfNormal("sigma", self.priors["sigma"])
            # We need one init variable for each lag, hence size is variable too
            init = pm.Normal.dist(
                self.priors["init"]["mu"], self.priors["init"]["sigma"], size=self.priors["init"]["size"]
            )
        
            ar = pm.AR(
                "ar",
                coefs,
                sigma=sigma,
                init_dist=init,
                constant=False,
                dims="obs_id",
            )

            # TREND params
            
            alpha = pm.Normal("alpha", self.priors["alpha"]["mu"], self.priors["alpha"]["sigma"])
            beta = pm.Normal("beta", self.priors["beta"]["mu"], self.priors["beta"]["sigma"])
            trend = pm.Deterministic("trend", alpha + beta * t, dims="obs_id")

            # SEASONAL params

            # beta prior for frequency since it's between 0 and 1; let's give ourselves an easier
            freq = pm.Beta("freq", alpha=self.priors["freq"]["alpha"], beta = self.priors["freq"]["beta"])
            # kind of a crappy choice of prior for amplitude but we could do worse
            amp = pm.Normal("amp", mu=self.priors["amp"]["mu"], sigma = self.priors["amp"]["sigma"])
            phase = pm.Uniform("phase", lower = -0.5, upper=0.5) # in this case we can hard code phase...we just pick uniform over the range
            
            seasonal = pm.Deterministic("seasonal", amp*np.sin(2*np.pi*freq*(t + phase)), dims="obs_id")
            
            mu = ar + trend + seasonal
            
            outcome = pm.Normal("likelihood", mu=ar, sigma=sigma, observed=y, dims="obs_id")
        
            self.idata = pm.sample_prior_predictive()
            self.idata.extend(pm.sample(2000, random_seed=100, target_accept=0.95))
            self.idata.extend(pm.sample_posterior_predictive(self.idata))

    def run_model_plus_forecast(self):

        with pm.Model() as SBTS:
        
            SBTS.add_coord("obs_id", self.t_train, mutable=True) # coords, mutable for prediction
        
            # data containers for time and 
            t = pm.MutableData("t", self.t_train, dims="obs_id")
            y = pm.MutableData("y", self.data_train, dims="obs_id")
        
            # now we build our priors for the AR model parameters
        
            # rho in the API, one per autoregression coefficient
            coefs = pm.Normal("coefs", self.priors["coefs"]["mu"], self.priors["coefs"]["sigma"])
            # standard deviation of our normal noise term
            sigma = pm.HalfNormal("sigma", self.priors["sigma"])
            # We need one init variable for each lag, hence size is variable too
            init = pm.Normal.dist(
                self.priors["init"]["mu"], self.priors["init"]["sigma"], size=self.priors["init"]["size"]
            )
        
            ar = pm.AR(
                "ar",
                coefs,
                sigma=sigma,
                init_dist=init,
                constant=False,
                dims="obs_id",
            )

            # TREND params
            
            alpha = pm.Normal("alpha", self.priors["alpha"]["mu"], self.priors["alpha"]["sigma"])
            beta = pm.Normal("beta", self.priors["beta"]["mu"], self.priors["beta"]["sigma"])
            trend = pm.Deterministic("trend", alpha + beta * t, dims="obs_id")

            # SEASONAL params

            # beta prior for frequency since it's between 0 and 1; let's give ourselves an easier
            freq = pm.Beta("freq", alpha=self.priors["freq"]["alpha"], beta = self.priors["freq"]["beta"])
            # kind of a crappy choice of prior for amplitude but we could do worse
            amp = pm.Normal("amp", mu=self.priors["amp"]["mu"], sigma = self.priors["amp"]["sigma"])
            phase = pm.Uniform("phase", lower = -0.5, upper=0.5) # in this case we can hard code phase...we just pick uniform over the range
            
            seasonal = pm.Deterministic("seasonal", amp*np.sin(2*np.pi*freq*(t + phase)), dims="obs_id")
            
            mu = ar + trend + seasonal
            
            outcome = pm.Normal("likelihood", mu=ar, sigma=sigma, observed=y, dims="obs_id")
        
            self.idata = pm.sample_prior_predictive()
            self.idata.extend(pm.sample(2000, random_seed=100, target_accept=0.95))
            self.idata.extend(pm.sample_posterior_predictive(self.idata))

            num_lags = self.ar_order
            # for now we let the code be inefficiently named and structured (due to copied from cell way above) instead focusing on no typos
            with SBTS:
                SBTS.add_coords({"obs_id_fut_lagged": range(len(self.data_train) - num_lags,len(self.data_test)+len(self.data_train),1 )})
                SBTS.add_coords({"obs_id_fut": self.t_test})

                t_fut = pm.MutableData(
                    "t_fut", self.t_test, dims="obs_id_fut"
                )
                ar_fut = pm.AR(
                    "ar_fut",
                    init_dist=pm.DiracDelta.dist(ar[..., -num_lags]),
                    rho=coefs,
                    sigma=sigma,
                    constant=False,
                    dims="obs_id_fut_lagged",
                )

                trend_fut = pm.Deterministic("trend_fut", alpha + beta * t_fut, dims="obs_id_fut")
                seasonal_fut = pm.Deterministic("seasonal_fut", amp*np.sin(2*np.pi*freq*(t_fut + phase)), dims="obs_id_fut")

                mu = ar_fut[num_lags:] + trend_fut + seasonal_fut
                yhat_fut = pm.Normal("yhat_fut", mu=mu, sigma=sigma, dims="obs_id_fut")
            
                # use the updated values and predict outcomes and probabilities:
                self.idata_preds = pm.sample_posterior_predictive(
                    self.idata, var_names=["likelihood", "yhat_fut"], predictions=True, random_seed=100
                )

    def plot_model(self):
        plt.figure(figsize=(20,5))
        self.idata.posterior_predictive.likelihood.mean(["chain", "draw"]).plot(label="Posterior Mean AR level")
        plt.plot(self.data_train,'o',color="black", markersize=2, label="Observed Data")
        plt.legend()

        plt.figure(figsize=(20,5))
        plt.plot(self.idata.posterior.trend.mean(['chain','draw']), label='Trend')
        plt.legend()

# %% [markdown]
# ### Investigate results
#
# It's not ideal...we are pretty sticky to our priors and this calls for investigation...but at the very least, we're able to fit the thing. Let's move on for now to what projection looks like.

# %%
priors = {
            "coefs": {"mu": [0, 0], "sigma": [1, 1], "size": 2},
            "sigma": 1,
            "init": {"mu": 10, "sigma": 3, "size": 2},
            "alpha":{"mu":0, "sigma":5},
            "beta":{"mu":0, "sigma":1},
            "amp":{"mu":10, "sigma":5},
            "freq":{"alpha":1,"beta":10}
        }

sbts = sbts_model(data_gen, priors)

# %%
sbts.run_model()
# Out:
# Sampling: [alpha, amp, ar, beta, coefs, freq, likelihood, phase, sigma]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [coefs, sigma, ar, alpha, beta, freq, amp, phase]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:12&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 13 seconds.
# Sampling: [likelihood]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00&lt;00:00]
#     </div>

# %%
az.summary(sbts.idata, var_names=["~ar"]).iloc[0:8,:]# uh oh! these are not right...
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# coefs[0]   0.214  0.046   0.132    0.302      0.001    0.001    4642.0
# coefs[1]   0.737  0.046   0.649    0.819      0.001    0.000    4715.0
# alpha      0.033  5.105  -9.528    9.608      0.036    0.072   19671.0
# beta       0.005  1.000  -1.825    1.930      0.007    0.014   18931.0
# amp       10.107  5.009   0.601   19.378      0.035    0.033   20020.0
# sigma      0.869  0.037   0.803    0.941      0.001    0.000    4199.0
# freq       0.092  0.084   0.000    0.247      0.001    0.001   10968.0
# phase      0.001  0.284  -0.489    0.446      0.002    0.004   17800.0
#
#           ess_tail  r_hat
# coefs[0]    4507.0    1.0
# coefs[1]    4582.0    1.0
# alpha       5097.0    1.0
# beta        5543.0    1.0
# amp         5155.0    1.0
# sigma       6202.0    1.0
# freq        4211.0    1.0
# phase       4533.0    1.0

# %%
sbts.idata.posterior.trend.mean(['chain','draw'])
# Out:
# <xarray.DataArray 'trend' (obs_id: 300)>
# array([0.03307422, 0.03840073, 0.04372725, 0.04905377, 0.05438029,
#        0.0597068 , 0.06503332, 0.07035984, 0.07568635, 0.08101287,
#        0.08633939, 0.0916659 , 0.09699242, 0.10231894, 0.10764546,
#        0.11297197, 0.11829849, 0.12362501, 0.12895152, 0.13427804,
#        0.13960456, 0.14493108, 0.15025759, 0.15558411, 0.16091063,
#        0.16623714, 0.17156366, 0.17689018, 0.18221669, 0.18754321,
#        0.19286973, 0.19819625, 0.20352276, 0.20884928, 0.2141758 ,
#        0.21950231, 0.22482883, 0.23015535, 0.23548187, 0.24080838,
#        0.2461349 , 0.25146142, 0.25678793, 0.26211445, 0.26744097,
#        0.27276749, 0.278094  , 0.28342052, 0.28874704, 0.29407355,
#        0.29940007, 0.30472659, 0.3100531 , 0.31537962, 0.32070614,
#        0.32603266, 0.33135917, 0.33668569, 0.34201221, 0.34733872,
#        0.35266524, 0.35799176, 0.36331828, 0.36864479, 0.37397131,
#        0.37929783, 0.38462434, 0.38995086, 0.39527738, 0.40060389,
#        0.40593041, 0.41125693, 0.41658345, 0.42190996, 0.42723648,
#        0.432563  , 0.43788951, 0.44321603, 0.44854255, 0.45386907,
#        0.45919558, 0.4645221 , 0.46984862, 0.47517513, 0.48050165,
#        0.48582817, 0.49115469, 0.4964812 , 0.50180772, 0.50713424,
#        0.51246075, 0.51778727, 0.52311379, 0.5284403 , 0.53376682,
#        0.53909334, 0.54441986, 0.54974637, 0.55507289, 0.56039941,
# ...
#        1.09837763, 1.10370415, 1.10903067, 1.11435718, 1.1196837 ,
#        1.12501022, 1.13033673, 1.13566325, 1.14098977, 1.14631629,
#        1.1516428 , 1.15696932, 1.16229584, 1.16762235, 1.17294887,
#        1.17827539, 1.1836019 , 1.18892842, 1.19425494, 1.19958146,
#        1.20490797, 1.21023449, 1.21556101, 1.22088752, 1.22621404,
#        1.23154056, 1.23686708, 1.24219359, 1.24752011, 1.25284663,
#        1.25817314, 1.26349966, 1.26882618, 1.2741527 , 1.27947921,
#        1.28480573, 1.29013225, 1.29545876, 1.30078528, 1.3061118 ,
#        1.31143831, 1.31676483, 1.32209135, 1.32741787, 1.33274438,
#        1.3380709 , 1.34339742, 1.34872393, 1.35405045, 1.35937697,
#        1.36470349, 1.37003   , 1.37535652, 1.38068304, 1.38600955,
#        1.39133607, 1.39666259, 1.4019891 , 1.40731562, 1.41264214,
#        1.41796866, 1.42329517, 1.42862169, 1.43394821, 1.43927472,
#        1.44460124, 1.44992776, 1.45525428, 1.46058079, 1.46590731,
#        1.47123383, 1.47656034, 1.48188686, 1.48721338, 1.4925399 ,
#        1.49786641, 1.50319293, 1.50851945, 1.51384596, 1.51917248,
#        1.524499  , 1.52982551, 1.53515203, 1.54047855, 1.54580507,
#        1.55113158, 1.5564581 , 1.56178462, 1.56711113, 1.57243765,
#        1.57776417, 1.58309069, 1.5884172 , 1.59374372, 1.59907024,
#        1.60439675, 1.60972327, 1.61504979, 1.62037631, 1.62570282])
# Coordinates:
#   * obs_id   (obs_id) int64 0 1 2 3 4 5 6 7 ... 292 293 294 295 296 297 298 299

# %%
sbts.plot_model()

# %% [markdown]
# ### Add Forecasting Back In

# %%
priors = {
            "coefs": {"mu": [0,], "sigma": [1, 1], "size": 2},
            "sigma": 1,
            "init": {"mu": 10, "sigma": 3, "size": 2},
            "alpha":{"mu":0, "sigma":1},
            "beta":{"mu":0, "sigma":1},
            "amp":{"mu":10, "sigma":5},
            "freq":{"alpha":1,"beta":20}
        }

sbts = sbts_model(data_gen, priors)
sbts.run_model_plus_forecast()
# Out:
# Sampling: [alpha, amp, ar, beta, coefs, freq, likelihood, phase, sigma]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [coefs, sigma, ar, alpha, beta, freq, amp, phase]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:11&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 12 seconds.
# Sampling: [likelihood]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00&lt;00:00]
#     </div>
# Sampling: [ar_fut, likelihood, yhat_fut]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:34&lt;00:00]
#     </div>

# %%
plt.plot(sbts.idata_preds.predictions.likelihood.mean(['chain','draw']))

# %%
plt.plot(sbts.idata_preds.predictions.yhat_fut.mean(['chain','draw']))

# %%
plt.plot(sbts.idata_preds.predictions.yhat_fut[1][4])

# %%
az.summary(sbts.idata, var_names=["~ar"]).iloc[0:8,:]# uh oh! these are not right...
# Out:
#            mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# coefs[0]  0.215  0.046   0.130    0.300      0.001    0.001    4555.0
# coefs[1]  0.736  0.046   0.647    0.817      0.001    0.000    4610.0
# alpha     0.002  1.026  -1.929    1.899      0.008    0.014   18701.0
# beta     -0.002  0.993  -1.802    1.908      0.007    0.014   20044.0
# amp       9.989  5.117   0.740   19.769      0.039    0.035   17029.0
# sigma     0.869  0.036   0.803    0.936      0.001    0.000    4053.0
# freq      0.048  0.046   0.000    0.133      0.000    0.000   10072.0
# phase    -0.003  0.287  -0.499    0.433      0.002    0.004   17762.0
#
#           ess_tail  r_hat
# coefs[0]    4367.0    1.0
# coefs[1]    4160.0    1.0
# alpha       5719.0    1.0
# beta        4858.0    1.0
# amp         5589.0    1.0
# sigma       5859.0    1.0
# freq        4213.0    1.0
# phase       4723.0    1.0

# %% [markdown]
# ## Uh Oh
#
# Things are looking pretty horrible. Let's use the plotting util from the tutorial to inspect with a bit more ease. Fortunately I kept the necessary naming conventions even though my model is very different. From this we can see we have a total explosion in the posterior :(
# maybe this is because the model didn't really converge on truth. Our coefficients are for an AR(2) process with coefficients 0,1.001. This leads to an explosion and that's what we seem to see in the posterior.
#
# So, our poor fit kind of dooms us here.

# %%
def plot_fits(idata_ar, idata_preds):
    palette = "plasma"
    cmap = plt.get_cmap(palette)
    percs = np.linspace(51, 99, 100)
    colors = (percs - np.min(percs)) / (np.max(percs) - np.min(percs))
    mosaic = """AABB
                CCCC"""
    fig, axs = plt.subplot_mosaic(mosaic, sharex=False, figsize=(20, 10))
    axs = [axs[k] for k in axs.keys()]
    for i, p in enumerate(percs[::-1]):
        upper = np.percentile(
            az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"],
            p,
            axis=1,
        )
        lower = np.percentile(
            az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"],
            100 - p,
            axis=1,
        )
        color_val = colors[i]
        axs[0].fill_between(
            x=idata_ar["constant_data"]["t"],
            y1=upper.flatten(),
            y2=lower.flatten(),
            color=cmap(color_val),
            alpha=0.1,
        )

    axs[0].plot(
        az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"].mean(
            axis=1
        ),
        color="cyan",
        label="Prior Predicted Mean Realisation",
    )

    axs[0].scatter(
        x=idata_ar["constant_data"]["t"],
        y=idata_ar["constant_data"]["y"],
        color="k",
        label="Observed Data points",
    )
    axs[0].set_title("Prior Predictive Fit", fontsize=20)
    axs[0].legend()

    for i, p in enumerate(percs[::-1]):
        upper = np.percentile(
            az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"],
            p,
            axis=1,
        )
        lower = np.percentile(
            az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"],
            100 - p,
            axis=1,
        )
        color_val = colors[i]
        axs[2].fill_between(
            x=idata_preds["predictions_constant_data"]["t"],
            y1=upper.flatten(),
            y2=lower.flatten(),
            color=cmap(color_val),
            alpha=0.1,
        )

        upper = np.percentile(
            az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["yhat_fut"],
            p,
            axis=1,
        )
        lower = np.percentile(
            az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["yhat_fut"],
            100 - p,
            axis=1,
        )
        color_val = colors[i]
        axs[2].fill_between(
            x=idata_preds["predictions"].coords["obs_id_fut"].data,
            y1=upper.flatten(),
            y2=lower.flatten(),
            color=cmap(color_val),
            alpha=0.1,
        )

    axs[2].plot(
        az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"].mean(
            axis=1
        ),
        color="cyan",
    )
    idata_preds.predictions.yhat_fut.mean(["chain", "draw"]).plot(
        ax=axs[2], color="cyan", label="Predicted Mean Realisation"
    )
    axs[2].scatter(
        x=idata_ar["constant_data"]["t"],
        y=idata_ar["constant_data"]["y"],
        color="k",
        label="Observed Data",
    )
    axs[2].set_title("Posterior Predictions Plotted", fontsize=20)
    axs[2].axvline(np.max(idata_ar["constant_data"]["t"]), color="black")
    axs[2].legend()
    axs[2].set_xlabel("Time in Days")
    axs[0].set_xlabel("Time in Days")
    az.plot_ppc(idata_ar, ax=axs[1])


plot_fits(sbts.idata, sbts.idata_preds)
# Out:
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:12: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:17: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:31: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"].mean(
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:49: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:54: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:68: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["yhat_fut"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:73: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["yhat_fut"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_36975/1585113812.py:87: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"].mean(

# %% [markdown]
# ### More Experiments
#
# What happens if we feed the model priors that are basically correctly specified? What will our results look like? This way we can test if our model fitting process is really the issue or if we've made some syntax errors.

# %%
priors = {
            "coefs": {"mu": [-0.9, 0.1], "sigma": [0.1, 0.1], "size": 2},
            "sigma": 1,
            "init": {"mu": 10, "sigma": 3, "size": 2},
            "alpha":{"mu":0, "sigma":5},
            "beta":{"mu":0.2, "sigma":1},
            "amp":{"mu":4, "sigma":5},
            "freq":{"alpha":1,"beta":50}
        }

priors = {
            "coefs": {"mu": [-.7,0.1], "sigma": [.1, .1], "size": 2},
            "sigma": 0.5,
            "init": {"mu": 10, "sigma": 3, "size": 2},
            "alpha":{"mu":0, "sigma":1},
            "beta":{"mu":0, "sigma":1},
            "amp":{"mu":10, "sigma":5},
            "freq":{"alpha":1,"beta":20}
        }

sbts_psychic = sbts_model(data_gen, priors)
sbts_psychic.run_model_plus_forecast()
# Out:
# Sampling: [alpha, amp, ar, beta, coefs, freq, likelihood, phase, sigma]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [coefs, sigma, ar, alpha, beta, freq, amp, phase]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:12&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 13 seconds.
# Sampling: [likelihood]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00&lt;00:00]
#     </div>
# Sampling: [ar_fut, likelihood, yhat_fut]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:34&lt;00:00]
#     </div>

# %%
az.summary(sbts_psychic.idata, var_names=["~ar"]).iloc[0:8] # still converging to the wrong coefficients...
# Out:
#            mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# coefs[0]  0.167  0.035   0.102    0.235      0.000    0.000    7515.0
# coefs[1]  0.763  0.036   0.693    0.826      0.000    0.000    7013.0
# alpha    -0.002  1.011  -1.875    1.907      0.007    0.014   22171.0
# beta     -0.010  1.000  -1.977    1.766      0.007    0.014   20012.0
# amp       9.945  4.982   0.564   19.056      0.036    0.033   19462.0
# sigma     0.867  0.036   0.799    0.933      0.001    0.000    4025.0
# freq      0.047  0.046   0.000    0.131      0.000    0.000    9822.0
# phase     0.003  0.284  -0.497    0.435      0.002    0.004   22711.0
#
#           ess_tail  r_hat
# coefs[0]    5794.0    1.0
# coefs[1]    5695.0    1.0
# alpha       5523.0    1.0
# beta        5360.0    1.0
# amp         5372.0    1.0
# sigma       5547.0    1.0
# freq        4238.0    1.0
# phase       4776.0    1.0

# %%
plot_fits(sbts_psychic.idata, sbts_psychic.idata_preds)
# Out:
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:12: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:17: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:31: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_ar, group="prior_predictive", num_samples=1000)["likelihood"].mean(
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:49: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:54: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:68: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["yhat_fut"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:73: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["yhat_fut"],
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_33466/1585113812.py:87: FutureWarning: extract_dataset has been deprecated, please use extract
#   az.extract_dataset(idata_preds, group="predictions", num_samples=1000)["likelihood"].mean(
